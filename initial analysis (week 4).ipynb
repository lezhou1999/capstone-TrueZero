# %%
#Week 4 work Junjie Zhang
# !pip install CoolProp #instal CoolProp function
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 29.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload() #import collected data
# Out:
#      <input type="file" id="files-eee3eba5-e506-4020-acfb-6a6f864ca316" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eee3eba5-e506-4020-acfb-6a6f864ca316">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("2024.07.05_CMB.csv")

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

# %%
df['TimeStamp'] = pd.to_datetime(df['TimeStamp'])

#first y-axis
fig, ax1 = plt.subplots(figsize=(10, 6))
color = 'tab:blue'
ax1.set_xlabel('Date and Time')
ax1.set_ylabel('Trailer Fill Status', color=color)
ax1.plot(df_filtered['TimeStamp'], df_filtered['V1_Status'], color=color, label='Trailer Fill Status')
ax1.tick_params(axis='y', labelcolor=color)

ax1 = plt.gca()
ax1.xaxis.set_major_locator(mdates.AutoDateLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.xticks(rotation=45)

# second y-axis
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Liquid Percentage in the Tank', color=color)
ax2.plot(df_filtered['TimeStamp'], df_filtered['LI1_TankPerc'], color=color, label='Liquid Percentage in the Tank')
ax2.tick_params(axis='y', labelcolor=color)


lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.title('Station replenishment process from 8am to 10am', fontsize=18, fontweight='bold')
fig.tight_layout()
plt.show()
